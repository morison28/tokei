# %% [markdown]
# - 因子分析と主成分分析の違い
#     - 結果が似てるので分かりにくいよね
# - 結果は似ている
#     - 因子：因子→データ
#     - 主成分：データ→主成分(→データ)
# - 思想は違う
#     - 因子
#         - 相関を用いて背後の構造を知りにいく
#             - 相関があるなら，裏には因子構造があり，その結果として相関が泡割れている
#             - **知りに行く，理解するための分析**
#     - 主成分
#         - 相関を用いて情報を圧縮する
#             - 相関があるなら，いらない情報を省けるよね
#             - **表現する，加工する分析**
# - 発展も違う
#     - 因子分析
#         - 構造方程式モデリング
#             - 因子分析の発展形
#             - 因子と因子の関係もOK
#             - 因子同士の相関もOK
#         - 階層ベイズモデリング
#         - グラフィカルモデリング
#         - 因果推論
#     - 主成分分析
#         - オートエンコーダー
#             - PCAは線形写像
#             - オートエンコーダは深層学習
#         - 単語分散表現･単語埋め込み

# %% [markdown]
# ためしてみる
# - 同じデータで因子負荷量ベクトルと主成分の重みベクトルを比較してみる
# - 因子得点vs主成分得点
#
# -
